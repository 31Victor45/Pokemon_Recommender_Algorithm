# %% [markdown]
# # Limpieza de los datos
#
# En este jupiter nos centraremos en obtener los pokemon del dataset desde primera a cuarta generacion y tambien nos aceguraremos que no haya mega evoluciones y que solo se incluya un pokemon original (es decir no aseptare variaciones o otras formas que pueda tener un pokemon, nos quedaremos con la forma base del mismo)

# %%
# Importamos las librerias necesarias
import pandas as pd
import numpy as np

# %%
# Trabajaremos con pokemons de la 1ra a las 4ta generacion
df_pkmn = pd.read_csv("pkmn.csv")
df_pkmn = df_pkmn.iloc[:553, :]
df_pkmn.shape
# Out:
# (553, 13)

# %%
# Filtramos los pokemon de primera generacion
df_pkmn_gen1 = df_pkmn[((df_pkmn["Generation"] == 1) & (~df_pkmn["Name"].str.contains(" "))) | (df_pkmn["Name"] == "Mr. Mime")]
df_pkmn_gen1
# Out:
#        #        Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur    Grass  Poison    318   45      49       49       65
# 1      2     Ivysaur    Grass  Poison    405   60      62       63       80
# 2      3    Venusaur    Grass  Poison    525   80      82       83      100
# 4      4  Charmander     Fire     NaN    309   39      52       43       60
# 5      5  Charmeleon     Fire     NaN    405   58      64       58       80
# ..   ...         ...      ...     ...    ...  ...     ...      ...      ...
# 159  147     Dratini   Dragon     NaN    300   41      64       45       50
# 160  148   Dragonair   Dragon     NaN    420   61      84       65       70
# 161  149   Dragonite   Dragon  Flying    600   91     134       95      100
# 162  150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 165  151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
# Filtramos los pokemon de segunda generacion
df_pkmn_gen2 = df_pkmn[(df_pkmn["Generation"] == 2) & (~df_pkmn['Name'].str.contains(' '))]
df_pkmn_gen2
# Out:
#        #       Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 166  152  Chikorita    Grass     NaN    318   45      49       65       49
# 167  153    Bayleef    Grass     NaN    405   60      62       80       63
# 168  154   Meganium    Grass     NaN    525   80      82      100       83
# 169  155  Cyndaquil     Fire     NaN    309   39      52       43       60
# 170  156    Quilava     Fire     NaN    405   58      64       58       80
# ..   ...        ...      ...     ...    ...  ...     ...      ...      ...
# 266  247    Pupitar     Rock  Ground    410   70      84       70       65
# 267  248  Tyranitar     Rock    Dark    600  100     134      110       95
# 269  249      Lugia  Psychic  Flying    680  106      90      130       90
# 270  250      Ho-oh     Fire  Flying    680  106     130       90      110
# 271  251     Celebi  Psychic   Grass    600  100     100      100      100
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
# Filtramos los pokemon de tercera generacion
df_pkmn_gen3 = df_pkmn[((df_pkmn["Generation"] == 3) & (~df_pkmn['Name'].str.contains(' '))) | (df_pkmn["Name"] == "DeoxysNormal Forme")]
df_pkmn_gen3
# Out:
#        #                Name   Type 1    Type 2  Total   HP  Attack  Defense  \
# 272  252             Treecko    Grass       NaN    310   40      45       35
# 273  253             Grovyle    Grass       NaN    405   50      65       45
# 274  254            Sceptile    Grass       NaN    530   70      85       65
# 276  255             Torchic     Fire       NaN    310   45      60       40
# 277  256           Combusken     Fire  Fighting    405   60      85       60
# ..   ...                 ...      ...       ...    ...  ...     ...      ...
# 421  382              Kyogre    Water       NaN    670  100     100       90
# 423  383             Groudon   Ground       NaN    670  100     150      140
# 425  384            Rayquaza   Dragon    Flying    680  105     150       90
# 427  385             Jirachi    Steel   Psychic    600  100     100      100
# 428  386  DeoxysNormal Forme  Psychic       NaN    600   50     150       50
#
# ...

# %%
# Filtramos los pokemon de cuarta generacion
df_pkmn_gen4 = df_pkmn[((df_pkmn["Generation"] == 4) & (~df_pkmn['Name'].str.contains(' '))) | (df_pkmn["Name"] == "WormadamPlant Cloak") | (df_pkmn["Name"] == "Mime Jr.")| (df_pkmn["Name"] == "GiratinaAltered Forme")| (df_pkmn["Name"] == "ShayminLand Forme")]
df_pkmn_gen4
# Out:
#        #               Name  Type 1    Type 2  Total   HP  Attack  Defense  \
# 432  387            Turtwig   Grass       NaN    318   55      68       64
# 433  388             Grotle   Grass       NaN    405   75      89       85
# 434  389           Torterra   Grass    Ground    525   95     109      105
# 435  390           Chimchar    Fire       NaN    309   44      58       44
# 436  391           Monferno    Fire  Fighting    405   64      78       52
# ..   ...                ...     ...       ...    ...  ...     ...      ...
# 547  489             Phione   Water       NaN    480   80      80       80
# 548  490            Manaphy   Water       NaN    600  100     100      100
# 549  491            Darkrai    Dark       NaN    600   70      90       90
# 550  492  ShayminLand Forme   Grass       NaN    600  100     100      100
# 552  493             Arceus  Normal       NaN    720  120     120      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# Unimos en un dataframe las 4 generaciones pokemon filtradas
df_pkmn_work = pd.concat([df_pkmn_gen1, df_pkmn_gen2, df_pkmn_gen3, df_pkmn_gen4], ignore_index=True)
df_pkmn_work
# Out:
#        #               Name  Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1          Bulbasaur   Grass  Poison    318   45      49       49
# 1      2            Ivysaur   Grass  Poison    405   60      62       63
# 2      3           Venusaur   Grass  Poison    525   80      82       83
# 3      4         Charmander    Fire     NaN    309   39      52       43
# 4      5         Charmeleon    Fire     NaN    405   58      64       58
# ..   ...                ...     ...     ...    ...  ...     ...      ...
# 488  489             Phione   Water     NaN    480   80      80       80
# 489  490            Manaphy   Water     NaN    600  100     100      100
# 490  491            Darkrai    Dark     NaN    600   70      90       90
# 491  492  ShayminLand Forme   Grass     NaN    600  100     100      100
# 492  493             Arceus  Normal     NaN    720  120     120      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# Ahora tomare el dataset ya modificado y y quitare la columna "Total" ya que esta no será util para el analisis exporatorio de datos que planeo hacer
#
# No obstante quiero mencionar que el sistema de recomendacion que planeo crear no tendra en cuenta la generacion a la que pertenezca el pokemon y si el mismo es legendario o no ya que si bien esta informacion seria util de cara al analisis exploratorio, no la encuetro practica a la hora de crear el sistema de recomendacion

# %%
df_pkmn_work.drop(columns=['Total']).to_csv('pkmn_exploratory.csv', index=False)

# %% [markdown]
# Ahora crearemos un csv que tomará los pokemon de las 4 generaciones antes filtradas y eliminaremos variables que no concideramos utiles para el sistema de recomendacion que queremos crear

# %%
df_pkmn_work.drop(columns=['Generation', 'Legendary', 'Total']).to_csv('df_pkmn_clean.csv', index=False)
